# %% [markdown]
# # Introduction
#
# This applied science project turns mathematical theory into clean, highly efficient functional software. Starting with fractals invented in my PhD research, this project builds an interactive tool that visualizes these objects and runs empirical complexity benchmarks on the underlying code.
#
# **Main steps of this project:**
#
# 1. **Algorithmize**: Convert a mathematical construction into a clean python algorithm.
# 2. **Vectorize**: The code is vectorized while keeping the underlying logic intact.
# 3. **Empirical Complexity Analysis**: A deep run time analysis  is performed to see how much faster the vectorized code is.
# 4. **Deploy**: [fractal.py](./fractal.py) contains the deployment code for the web app.
#
# [Interactive web app](https://visualize-fractals-realtime.streamlit.app/): Displays real-time rendering with parameter manipulation and runtime benchmarks.
#
# **Dictionary:**
#
# 1. Fractal: For our purpose, a fractal is simply a shape with intricate geometry that "looks" the same upon zooming into the shape.
# 2. Koch Snowflake: This phrase always refers to Koch's original construction of his namesake fractal.
# 3. Modified Snowflakes: This is an infinite family of snowflake like curves of which Koch is a special case.
#
# Here an abridged version of my dissertation if you're curious about the math behind this project: [see section 2.2](https://scholarspace.manoa.hawaii.edu/server/api/core/bitstreams/31ac5794-df3a-4efa-b2cf-27ec43a9976a/content).

# %% [markdown]
# ## Motivation: Koch Snowflake
#
# The main motivation is Helge von Koch's famous [snowflake curve](https://en.wikipedia.org/wiki/Koch_snowflake). It is constructed as follows. Start with an equilateral triangle of unit side-length. Replace the middle thirds of each segment of the triangle by the other two sides of the outward pointing equilateral triangle of side length 1/3. Iterate this process on every resulting segment. The object resulting as a culmination of this process is called Koch's snowflake. Here's a picture of the first three steps of the process taken from Wikipedia:
# <div style = "text-align: center;">
#   <img src = "plots/KochFlake.svg.webp" width="500">
# </div>

# %% [markdown]
# ## Modified Snowflakes
#
# We will modify Koch's construction to obtain an infinite family of such snowflakes. Fix a number $a$ satisfying $1/4\le a < 1/3$. Consider the segment $[0,1]$ on the x-axis; this is the zeroth generation of the curve. Remove the middle open interval of length $a$ and replace it by the other two sides of the equilateral triangle of side length $a$. This is the first generation of the process. In the second step, replace the middle interval of length $a^2$ from each edge of the first generation curve with the other two sides of the equilateral triangle of side length $a^2$. At the $k^\text{th}$ generation, remove the middle interval of length $a^k$ from each of the $4^{k-1}$ edges of the previous generation and replace them by the other two sides of the equilateral triangle of length $a^k$. The limit of this process yields a fractal curve that we informally term "modified snowflake".
#
# **Dictionary**:
#
# 1. Scaling Factor ($a$): This parameter determines the shape of the snowflake. Snowflakes with small $a$ are thin and pointy, whereas snowflakes with a large $a$ are round and curvy.
# 2. Generation ($k$): This parameter gives the resolution for a snowflake with fixed scaling factor $a$. Increasing $k$ improves a snowflake's resolution.
# 3. Koch Snowflake: Snowflake with $a = 1/3$.
# 4. Modified Snowflakes: Any snowflake with $a$ satisfying $1/4 \le a < 1/3$.
#
# We begin by implementing this recursive logic using a simple for loop.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# Function to generate a modified snowflake curve.

# Parameters:
#    points: The starting segment. i.e., the zeroth generation of the fractal. 
#    k: The starting step counter. Cannot be initialized inside the function body since the function calls itself within its body.
#    max_gen: number of iterations we wish to perform.
#    a: A fixed number between 1/4 and 1/3 that determines the shape of the fractal. 
#    side_length : the side length of the starting equilateral triangle.

def modified_snowflake(max_gen, a, side_length = 1.0):
    
    def modified_koch_curve(points, k, max_gen, a):
        # Stop recursion when max generation is reached.
        if k > max_gen:
            return points
            
        new_points = []
    
        # Compute base length for current generation k.
        r = (a) ** k  
    
        # Process each segment sequentially.
        for i in range(len(points) - 1):
            A = np.array(points[i])
            B = np.array(points[i + 1])
            AB = B - A
            L = np.linalg.norm(AB)
    
            # Determine unit direction and perpendicular normal vector.
            unit_AB = AB / L
            normal = np.array([-unit_AB[1], unit_AB[0]])  
    
            # Calculate base length of new triangles and margins along current segment.
            base_length = r 
            margin = (L - base_length) / 2
    
            # Locate base end-points P1 and P2, and midpoint M.
            P1 = A + unit_AB * margin          
            P2 = A + unit_AB * (margin + base_length)  
            M = (P1 + P2) / 2                   
    
            # Calculate the peak vertex of the new triangle.
            height = (np.sqrt(3) / 2) * base_length
            P3 = M + normal * height        
    
            # Append transformed sequence of 4 points replacing segment AB.
            new_points += [tuple(A), tuple(P1), tuple(P3), tuple(P2)]
    
        # Re-attach final endpoint to complete the segment.
        new_points.append(tuple(points[-1]))  
    
        # Iterate/recurse to next generation with updated point list.
        return modified_koch_curve(new_points, k + 1, max_gen,a)

    # Define the 3 vertices of an equilateral triangle.
    p1 = (0.0, 0.0)
    p2 = (side_length, 0.0)
    p3 = (side_length / 2.0, (np.sqrt(3) / 2.0) * side_length)
    
    # Define the initial closed loop (0th generation).
    initial_triangle = [p1, p3, p2, p1]
    
    # Generate the fractal curve across all 3 sides simultaneously.
    return modified_koch_curve(initial_triangle, k = 1, max_gen = max_gen, a = a)

# %% [markdown]
# Let's visualize one of these modified snowflakes and compare it to the standard Koch snowflake. Since we'll make only one such plot, we refrain from writing a function for it.

# %%
# Create a figure with 1 row and 2 columns.
fig, axes = plt.subplots(1, 2, figsize = (12, 6))

# Plot 1: a = 1/3.6 (modified snowflake)
snowflake1 = modified_snowflake(5, 1/3.6, 1.0)
x1, y1 = zip(*snowflake1)

axes[0].plot(x1, y1, color = "midnightblue", linewidth = 1.0)
axes[0].set_aspect("equal")
axes[0].axis("off")
axes[0].set_title("Modified Snowflake (a = 1/3.6, gen = 5)", fontsize = 12)

# Plot 2: a = 1/3 (standard Koch snowflake)
snowflake2 = modified_snowflake(5, 1/3, 1.0)
x2, y2 = zip(*snowflake2)

axes[1].plot(x2, y2, color = "midnightblue", linewidth = 1.0)
axes[1].set_aspect("equal")
axes[1].axis("off")
axes[1].set_title("Koch Snowflake (a = 1/3, gen = 5)", fontsize = 12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Vectorize the Code
#
# We now proceed to vectorize the code above to create a singular function that returns a modified snowflake.

# %%
def vectorized_snowflake(max_gen, a, side_length = 1.0):

    def vectorized_modified_koch(points, k, max_gen, a):
        # Stop recursion when max generation is reached.
        if k > max_gen:
            return points
    
        # Ensure input is a 2D float NumPy array.
        pts = np.asarray(points, dtype = float)
    
        # Compute base length for current generation k.
        r = (a) ** k  
    
        # Process each segment sequentially.
        A = pts[:-1]
        B = pts[1:]
        AB = B - A
        L = np.linalg.norm(AB, axis = 1, keepdims = True)
    
        # Determine unit direction and perpendicular normal vector.
        unit_AB = AB / L
        normal = np.column_stack((-unit_AB[:, 1], unit_AB[:, 0]))
    
        # Calculate base length of new triangles and margins along current segment.
        base_length = r 
        margin = (L - base_length) / 2
    
        # Locate base end-points P1 and P2, and midpoint M.
        P1 = A + unit_AB * margin
        P2 = A + unit_AB * (margin + base_length)
        M = (P1 + P2) / 2
    
        # Calculate the peak vertex of the new triangle.
        height = (np.sqrt(3) / 2) * base_length
        P3 = M + normal * height
    
        # Allocate single array for transformed points plus the final endpoint.
        num_segments = len(A)
        new_points = np.empty((num_segments * 4 + 1, 2), dtype=float)
        new_points[0:-1:4] = A
        new_points[1:-1:4] = P1
        new_points[2:-1:4] = P3
        new_points[3:-1:4] = P2
    
        # Re-attach final endpoint to complete the segment.
        new_points[-1] = pts[-1]
    
        # Iterate/recurse to next generation with updated point list.
        return vectorized_modified_koch(new_points, k + 1, max_gen, a)
    
    # Define the 3 vertices of an equilateral triangle.
    p1 = (0.0, 0.0)
    p2 = (side_length, 0.0)
    p3 = (side_length / 2.0, (np.sqrt(3) / 2.0) * side_length)

    initial_triangle = np.array([p1, p3, p2, p1], dtype = float)

    # Generate and return the modified snowflake.
    return vectorized_modified_koch(initial_triangle, k = 1, max_gen = max_gen, a = a)

# %%
# A function to plot snowflakes using the vectorized code.

def plot_vectorized_snowflake(title):
    
    # Generate modified snowflake.
    snowflake = vectorized_snowflake(max_gen, a, side_length)
        
    plt.figure(figsize = (6, 6))
    plt.plot(snowflake[:, 0], snowflake[:, 1], color = "midnightblue", linewidth = 1.0)
    plt.gca().set_aspect("equal")
    plt.axis("off")            
    plt.title(title)
    plt.show()

# %% [markdown]
# Let's ensure that our vectorized code works correctly. To have some variety, let's plot the limit of this fractal process as the parameter approaches 1/4, i.e., a = 1/4.

# %%
max_gen = 10
a = 1/4
title = 'Vectorized Modified Snowflake'
side_length = 1

plot_vectorized_snowflake(title)

# %% [markdown]
# ## Run Time Analysis
#
# We now check how much faster the vectorized code is. We use %timeit for this purpose.

# %%
def run_time(max_gen, a, side_length = 1.0):
    
    # Run time for unvectorized code 
    # -o saves output object and -q stops the automatic printing of %timeit.
    unvec_res = %timeit -o -q modified_snowflake(max_gen = max_gen, a = a, side_length = side_length)
    unvec_time = unvec_res.best * 1000  # .best Runs several times and finds the shortest run time.

    # Run time for vectorized code.
    vec_res = %timeit -o -q vectorized_snowflake(max_gen = max_gen, a = a, side_length = side_length)
    vec_time = vec_res.best * 1000  

    # Calculate total computed vertices of triangles.
    number_of_points = len(vectorized_snowflake(max_gen = max_gen, a = a, side_length = side_length))

    return unvec_time, vec_time, number_of_points

# %%
max_gen = 7
a = 1 / 3.6
side_length = 1

unvec_time, vec_time, number_of_points = run_time(max_gen, a, side_length)

# Print stats
print(f"Generation: {max_gen}")
print(f"Total Points Computed: {number_of_points}")
print(f"Run time for unvectorized code: {unvec_time:.3f} ms")
print(f"Run time for vectorized code: {vec_time:.3f} ms")
print(f"Speedup factor: {unvec_time / vec_time:.2f}x faster")
# Out:
# Generation: 7
# Total Points Computed: 49153
# Run time for unvectorized code: 475.806 ms
# Run time for vectorized code: 3.609 ms
# Speedup factor: 131.83x faster

# %% [markdown]
# These results are very encouraging. Let's formally compare both versions of the code for each step of a fractal's generation.

# %%
# Setup parameter range and initialize.
generations = list(range(1, 11))
unvec_times = []
vec_times = []
point_counts = []  # Store total points for top axis.

a = 1 / 3.6
side_len = 1.0

# Collect run time results and point counts using run_time.
for k in generations:
    t_unvec, t_vec, n_pts = run_time(max_gen = k, a = a, side_length = side_len)
    unvec_times.append(t_unvec)
    vec_times.append(t_vec)
    point_counts.append(n_pts)

# Create figure and bottom axis.
fig, ax1 = plt.subplots(figsize = (9, 5.5))

# Plot performance lines on primary axis.
line1 = ax1.plot(generations, unvec_times, marker = 'o', color = 'firebrick', linewidth = 2, label = 'Unvectorized (Python Lists)')
line2 = ax1.plot(generations, vec_times, marker = 's', color = 'navy', linewidth = 2, label = 'Vectorized (NumPy Arrays)')

# Axes.
ax1.set_yscale('log')
ax1.set_xlabel('Generation', fontsize = 11, labelpad = 8)
ax1.set_ylabel('Run Time (ms, log scale)', fontsize = 11)
ax1.set_xticks(generations)
ax1.grid(True, which = "both", linestyle = "--", alpha = 0.5)

# 4. Create top x-axis for point count
ax2 = ax1.twiny()
ax2.set_xlim(ax1.get_xlim())  # Synchronize limits with bottom axis
ax2.set_xticks(generations)   # Map ticks directly to k values.

# Generate label points for top axis. 
def format_pts(n):
    if n >= 1_000_000:
        return f"{n/1_000_000:.1f}M"
    elif n >= 1_000:
        return f"{n/1_000:.0f}k"
    return str(n)

top_labels = [format_pts(p) for p in point_counts]
ax2.set_xticklabels(top_labels, fontsize = 9, rotation = 25)
ax2.set_xlabel('Total Points Computed', fontsize = 11, labelpad = 10)

# Title & Legend.
plt.title('Fractal Generation Run Time Comparison', fontsize = 13, fontweight = 'bold', pad = 20)

lines = line1 + line2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, frameon = True, facecolor = 'white', framealpha = 0.9, loc = 'upper left')


plt.tight_layout()
# plt.savefig("runtime_plot.png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# # Results
#
# Let's analyze the plot above. Fix the scaling factor $a$. The above plot shows how run time scales as the generation of the snowflake increases.
#
# 1. **Total Points Computed**: As the generation ($k$) increases, the total number of points to be computed grows as $\mathcal{O}(4^k)$. This checks out with how the snowflake is constructed: Each iteration replaces 1 segment with 4 sub-segments.
# 2. **Run Time**: The curve for unvectorized code is a straight line in a log-scaled graph: this means that both the Total Points Computed and Run Time grow **exponentially**.
# 3. **Scaling**: At small generations (k<4), the vertical gap between vectorized and unvectorized code grows consistently and the gap becomes roughly constant as $k$ keeps growing. This indicates that the **relative speedup factor (>100x)** becomes roughly constant as the snowflake's resolution (generation) increases.
#
# Vectorizing this code enabled us to create real time visualization in our app: [](). For example a generation 10 snowflake takes several minutes to render while vectorized code does it in less than a second.
